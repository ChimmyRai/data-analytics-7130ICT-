# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline

jobs=pd.read_csv('job-market.csv')
jobs.head()
sns.set(font_scale=0.5)

sns.countplot(data=jobs, y="Location")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Location'>

# %%
salaryGroupedDF=jobs.groupby(pd.cut(jobs['HighestSalary'], bins=[0, 30, 40, 50, 60],labels=['0 to 30', '30 to 40', '40 to 50',
                            '50 to 60']))['Requirement'].count().reset_index()

#salaryGroupedDF
#list(salaryGroupedDF.columns)
#sns.barplot(data=salaryGroupedDF, x="HighestSalary", y="Requirement")

label_list = salaryGroupedDF.HighestSalary.values.tolist()
count_list = salaryGroupedDF.Requirement.values.tolist()
plt.title("Jobs post by salary range")
plt.pie(count_list, labels=label_list, colors=palette_color, autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x20e155c8a60>,
# ...
#  [Text(0.38693785945960824, 1.029698544680343, '0 to 30'),
#   Text(-1.0883136102638538, 0.15991712139247855, '30 to 40'),
#   Text(-0.38757836308420895, -1.029457630244667, '40 to 50'),
#   Text(0.923929845284454, -0.5969536338717146, '50 to 60')],
#  [Text(0.21105701425069537, 0.5616537516438235, '39%'),
#   Text(-0.5936256055984657, 0.08722752075953374, '18%'),
#   Text(-0.21140637986411395, -0.5615223437698182, '25%'),
#   Text(0.5039617337915203, -0.3256110730209352, '18%')])
