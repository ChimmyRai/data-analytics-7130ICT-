# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import matplotlib.pyplot as plt
digits=datasets.load_digits()
x=digits.data
y=digits.target
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
Accuracy_scores_train= []
Accuracy_scores_test= []
k_values=[]
data_type=[]
lst=[]

  
# Print data.
df
for k in range(1,8):
    kNN=KNeighborsClassifier(n_neighbors=k)
    kNN.fit(x_train,y_train)
    Accuracy_scores_train.append(kNN.score(x_train,y_train))
    Accuracy_scores_test.append(kNN.score(x_test,y_test))
    k_values.append(k)
    lst.append([k, kNN.score(x_train,y_train),'train data'])
    lst.append([k,kNN.score(x_test,y_test),'test data'])


df = pd.DataFrame(lst, columns =['k neighbours', 'Accuracy', 'type'])
df
# Out:
# C:\Users\mohun\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
import seaborn as sns
sns.lineplot(data=df, x="k neighbours", y="Accuracy", hue="type")
# Out:
# <AxesSubplot:xlabel='k neighbours', ylabel='Accuracy'>

# %% [markdown]
# since there is minimum error (both test and train data) when k=1, the best number of neighbours should be 1

# %%
from sklearn.model_selection import cross_validate
from sklearn.metrics import classification_report

from sklearn.svm import SVC
svm=SVC(kernel="linear")
svm.fit(x_train,y_train)
y_predict=svm.predict(x_test)
print(classification_report(y_test,y_predict))

svm=SVC(kernel="poly")
svm.fit(x_train,y_train)
y_predict=svm.predict(x_test)
print(classification_report(y_test,y_predict))

svm=SVC(kernel="rbf")
svm.fit(x_train,y_train)
y_predict=svm.predict(x_test)
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        32
#            1       1.00      0.98      0.99        42
#            2       1.00      1.00      1.00        31
#            3       1.00      0.95      0.97        37
#            4       0.97      1.00      0.99        35
#            5       0.94      1.00      0.97        30
#            6       1.00      0.97      0.99        36
#            7       0.98      1.00      0.99        41
#            8       0.91      0.97      0.94        30
#            9       1.00      0.96      0.98        46
#
#     accuracy                           0.98       360
#    macro avg       0.98      0.98      0.98       360
# weighted avg       0.98      0.98      0.98       360
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        32
#            1       1.00      1.00      1.00        42
# ...

# %% [markdown]
# polynomial kernel is best for image processing

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
bayes=GaussianNB()
bayes.fit(x_train,y_train)
y_predict=bayes.predict(x_test)
matrix=confusion_matrix(y_test,y_predict)

sns.heatmap(matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
accuracydataframe=pd.DataFrame({"classifier algorithm":["KNN","SVM","GAUSSIAN NAVE BIAS"],"Accuracy score":[kNN.score(x_train,y_train),svm.score(x_train,y_train),bayes.score(x_train,y_train)]})
accuracydataframe
sns.barplot(data=accuracydataframe, x="classifier algorithm", y="Accuracy score")
# Out:
# C:\Users\mohun\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# <AxesSubplot:xlabel='classifier algorithm', ylabel='Accuracy score'>

# %%
newDF=pd.read_csv("gapminder.csv")
newDF.head()
# Out:
#    population  fertility  HIV        CO2  BMI_male    GDP  BMI_female  life  \
# 0    34811059       2.73  0.1   3.328945  24.59620  12314    129.9049  75.3
# 1    19842251       6.43  2.0   1.474353  22.25083   7103    130.1247  58.3
# 2    40381860       2.24  0.5   4.785170  27.50170  14646    118.8915  75.5
# 3     2975029       1.40  0.1   1.804106  25.35542   7383    132.8108  72.5
# 4    21370348       1.96  0.1  18.016313  27.56373  41312    117.3755  81.5
#
#    child_mortality                      Region
# 0             29.5  Middle East & North Africa
# 1            192.0          Sub-Saharan Africa
# 2             15.4                     America
# 3             20.0       Europe & Central Asia
# 4              5.2         East Asia & Pacific

# %%
sns.heatmap(newDF.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
x=np.array(newDF["fertility"]).reshape(-1, 1)
y=np.array(newDF['life']).reshape(-1, 1)

regression=LinearRegression()
regression.fit(x,y)
fig, ax=plt.plot(x,y,"bo",x,regression.predict(x),'-k')

# %%
xx=newDF[["fertility","HIV","CO2","BMI_male","GDP","BMI_female","child_mortality"]]
y=newDF['life']
regression2=LinearRegression()
regression2.fit(xx,y)
fig, ax=plt.plot(xx,y,"bo",xx,regression2.predict(xx),'-k')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19048\4036290540.py in <module>
#       3 regression2=LinearRegression()
#       4 regression2.fit(xx,y)
# ----> 5 fig, ax=plt.plot(xx,y,"bo",xx,regression2.predict(xx),'-k')
#
# ValueError: too many values to unpack (expected 2)

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(regression,x,y,cv=5)
# Out:
# array([0.71001079, 0.75007717, 0.55271526, 0.547501  , 0.52410561])

# %%
cross_val_score(regression,xx,y,cv=5)
# Out:
# array([0.81621881, 0.8322471 , 0.90868335, 0.81325568, 0.94404223])

# %%
df=pd.read_csv("creditcard.csv")
#df.head()
frauds=df[df["Class"]==1]
#frauds.head()
non_frauds=df[df["Class"]==0]
#non_frauds.head()
plt.xlabel("Amount")
plt.ylabel("Class")

plt.plot(frauds.Amount,frauds.Class,"o",color="orange",label="Frauds")
plt.plot(non_frauds.Amount,non_frauds.Class,"o",color="blue",label="non frauds")
plt.legend()

# %% [markdown]
# Fraud transactions are usually <=5000

# %%
from sklearn.linear_model import LogisticRegression
x=df.drop("Class",axis=1)
y=df.Class
log_regression=LogisticRegression(solver="lbfgs",max_iter=400)
log_regression.fit(x,y)
y_predict=log_regression.predict(x)
matrix=confusion_matrix(y,y_predict)
print(matrix)
sns.heatmap(matrix, annot=True)
# Out:
# [[284257     58]
#  [   186    306]]
# <AxesSubplot:>

# %%
from skimage import io
from sklearn.cluster import KMeans

#Read the image
image = io.imread('goldcoast.jpeg')
io.imshow(image)
io.show()
#Dimension of the original image
rows = image.shape[0]
cols = image.shape[1]
#Flatten the image
image = image.reshape(rows*cols, 3)
#Implement k-means clustering to form k clusters
kmeans = KMeans(n_clusters=4)
kmeans.fit(image)

#Replace each pixel value with its nearby centroid
compressed_image = kmeans.cluster_centers_[kmeans.labels_]
compressed_image = np.clip(compressed_image.astype('uint8'), 0, 255)

#Reshape the image to original dimension
compressed_image = compressed_image.reshape(rows, cols, 3)

#Save and display output image
io.imsave('compressed_image_64.png', compressed_image)
io.imshow(compressed_image)
io.show()
